# %% [markdown]
# # OCR For Text Extraction
# ---
# ## 1. Installing Packages & Import Modules
# Packages required to do text extraction are:
# - **TensorFlow**
# : Text detection and text recognition model builder
# - **PyPDF2**
# : PDF document handler, capable of retrieve text and metadata from PDFs
# - **DocTR**
# : OCR logic handler, capable for parsing textual information from document or images

# %%
import sys
# !{sys.executable} -m pip install tensorflow
# !{sys.executable} -m pip install PyPDF2
# !{sys.executable} -m pip install python-doctr
# !{sys.executable} -m pip install python-doctr[tf]
# !{sys.executable} -m pip install python-doctr[torch]
# Out:
# Requirement already satisfied: tensorflow in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.0.7)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (20.9)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (67.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.53.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Requirement already satisfied: PyPDF2 in c:\python311\lib\site-packages (3.0.1)
# Requirement already satisfied: python-doctr in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (0.6.0)
# Requirement already satisfied: importlib-metadata in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (6.6.0)
# Requirement already satisfied: numpy<2.0.0,>=1.16.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (1.23.5)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (1.10.1)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (3.8.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in c:\python311\lib\site-packages (from python-doctr) (4.7.0.72)
# Requirement already satisfied: pypdfium2<4.0.0,>=3.0.0 in c:\python311\lib\site-packages (from python-doctr) (3.21.1)
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in c:\python311\lib\site-packages (from python-doctr) (1.3.0.post4)
# Requirement already satisfied: shapely<2.0.0,>=1.6.0 in c:\python311\lib\site-packages (from python-doctr) (1.8.5.post1)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (1.0.9)
# Requirement already satisfied: matplotlib>=3.1.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (3.7.1)
# Requirement already satisfied: weasyprint>=55.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (59.0)
# Requirement already satisfied: Pillow>=8.3.2 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (9.5.0)
# Requirement already satisfied: defusedxml>=0.7.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (0.7.1)
# Requirement already satisfied: mplcursors>=0.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (0.5.2)
# Requirement already satisfied: unidecode>=1.0.0 in c:\python311\lib\site-packages (from python-doctr) (1.3.6)
# Requirement already satisfied: tqdm>=4.30.0 in c:\python311\lib\site-packages (from python-doctr) (4.65.0)
# Requirement already satisfied: rapidfuzz>=1.6.0 in c:\python311\lib\site-packages (from python-doctr) (2.15.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr) (0.14.1)
# Requirement already satisfied: filelock in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr) (3.12.0)
# Requirement already satisfied: fsspec in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr) (2023.5.0)
# Requirement already satisfied: requests in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr) (20.9)
# Requirement already satisfied: six in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from langdetect<2.0.0,>=1.0.9->python-doctr) (1.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr) (2.8.2)
# Requirement already satisfied: colorama in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tqdm>=4.30.0->python-doctr) (0.4.6)
# Requirement already satisfied: pydyf>=0.6.0 in c:\python311\lib\site-packages (from weasyprint>=55.0->python-doctr) (0.6.0)
# Requirement already satisfied: cffi>=0.6 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr) (1.15.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr) (1.1)
# Requirement already satisfied: tinycss2>=1.0.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr) (1.2.1)
# Requirement already satisfied: cssselect2>=0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr) (0.7.0)
# Requirement already satisfied: Pyphen>=0.9.1 in c:\python311\lib\site-packages (from weasyprint>=55.0->python-doctr) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\python311\lib\site-packages (from importlib-metadata->python-doctr) (3.15.0)
# Requirement already satisfied: pycparser in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from cffi>=0.6->weasyprint>=55.0->python-doctr) (2.21)
# Requirement already satisfied: webencodings in c:\python311\lib\site-packages (from cssselect2>=0.1->weasyprint>=55.0->python-doctr) (0.5.1)
# Requirement already satisfied: zopfli>=0.1.4 in c:\python311\lib\site-packages (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr) (0.2.2)
# Requirement already satisfied: brotli>=1.0.1 in c:\python311\lib\site-packages (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr) (1.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr) (2022.12.7)
# Requirement already satisfied: python-doctr[tf] in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (0.6.0)
# Requirement already satisfied: importlib-metadata in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (6.6.0)
# Requirement already satisfied: numpy<2.0.0,>=1.16.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (1.23.5)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (1.10.1)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (3.8.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in c:\python311\lib\site-packages (from python-doctr[tf]) (4.7.0.72)
# Requirement already satisfied: pypdfium2<4.0.0,>=3.0.0 in c:\python311\lib\site-packages (from python-doctr[tf]) (3.21.1)
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in c:\python311\lib\site-packages (from python-doctr[tf]) (1.3.0.post4)
# Requirement already satisfied: shapely<2.0.0,>=1.6.0 in c:\python311\lib\site-packages (from python-doctr[tf]) (1.8.5.post1)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (1.0.9)
# Requirement already satisfied: matplotlib>=3.1.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (3.7.1)
# Requirement already satisfied: weasyprint>=55.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (59.0)
# Requirement already satisfied: Pillow>=8.3.2 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (9.5.0)
# Requirement already satisfied: defusedxml>=0.7.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (0.7.1)
# Requirement already satisfied: mplcursors>=0.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (0.5.2)
# Requirement already satisfied: unidecode>=1.0.0 in c:\python311\lib\site-packages (from python-doctr[tf]) (1.3.6)
# Requirement already satisfied: tqdm>=4.30.0 in c:\python311\lib\site-packages (from python-doctr[tf]) (4.65.0)
# Requirement already satisfied: rapidfuzz>=1.6.0 in c:\python311\lib\site-packages (from python-doctr[tf]) (2.15.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (0.14.1)
# Requirement already satisfied: tensorflow<3.0.0,>=2.9.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (2.12.0)
# Requirement already satisfied: tensorflow-addons>=0.17.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (0.20.0)
# Requirement already satisfied: tf2onnx>=1.9.2 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[tf]) (1.14.0)
# Requirement already satisfied: filelock in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[tf]) (3.12.0)
# Requirement already satisfied: fsspec in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[tf]) (2023.5.0)
# Requirement already satisfied: requests in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[tf]) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[tf]) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[tf]) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[tf]) (20.9)
# Requirement already satisfied: six in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from langdetect<2.0.0,>=1.0.9->python-doctr[tf]) (1.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[tf]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[tf]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[tf]) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[tf]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[tf]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[tf]) (2.8.2)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (2.0.7)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (0.2.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (67.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (2.2.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (1.53.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (0.31.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in c:\python311\lib\site-packages (from tensorflow-addons>=0.17.1->python-doctr[tf]) (2.13.3)
# Requirement already satisfied: onnx>=1.4.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tf2onnx>=1.9.2->python-doctr[tf]) (1.14.0)
# Requirement already satisfied: colorama in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tqdm>=4.30.0->python-doctr[tf]) (0.4.6)
# Requirement already satisfied: pydyf>=0.6.0 in c:\python311\lib\site-packages (from weasyprint>=55.0->python-doctr[tf]) (0.6.0)
# Requirement already satisfied: cffi>=0.6 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr[tf]) (1.15.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr[tf]) (1.1)
# Requirement already satisfied: tinycss2>=1.0.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr[tf]) (1.2.1)
# Requirement already satisfied: cssselect2>=0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr[tf]) (0.7.0)
# Requirement already satisfied: Pyphen>=0.9.1 in c:\python311\lib\site-packages (from weasyprint>=55.0->python-doctr[tf]) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\python311\lib\site-packages (from importlib-metadata->python-doctr[tf]) (3.15.0)
# Requirement already satisfied: pycparser in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from cffi>=0.6->weasyprint>=55.0->python-doctr[tf]) (2.21)
# Requirement already satisfied: webencodings in c:\python311\lib\site-packages (from cssselect2>=0.1->weasyprint>=55.0->python-doctr[tf]) (0.5.1)
# Requirement already satisfied: zopfli>=0.1.4 in c:\python311\lib\site-packages (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr[tf]) (0.2.2)
# Requirement already satisfied: brotli>=1.0.1 in c:\python311\lib\site-packages (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr[tf]) (1.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr[tf]) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr[tf]) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr[tf]) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr[tf]) (2022.12.7)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (0.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow<3.0.0,>=2.9.0->python-doctr[tf]) (3.2.2)
# Requirement already satisfied: python-doctr[torch] in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (0.6.0)
# Requirement already satisfied: importlib-metadata in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (6.6.0)
# Requirement already satisfied: numpy<2.0.0,>=1.16.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (1.23.5)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (1.10.1)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (3.8.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in c:\python311\lib\site-packages (from python-doctr[torch]) (4.7.0.72)
# Requirement already satisfied: pypdfium2<4.0.0,>=3.0.0 in c:\python311\lib\site-packages (from python-doctr[torch]) (3.21.1)
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in c:\python311\lib\site-packages (from python-doctr[torch]) (1.3.0.post4)
# Requirement already satisfied: shapely<2.0.0,>=1.6.0 in c:\python311\lib\site-packages (from python-doctr[torch]) (1.8.5.post1)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (1.0.9)
# Requirement already satisfied: matplotlib>=3.1.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (3.7.1)
# Requirement already satisfied: weasyprint>=55.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (59.0)
# Requirement already satisfied: Pillow>=8.3.2 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (9.5.0)
# Requirement already satisfied: defusedxml>=0.7.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (0.7.1)
# Requirement already satisfied: mplcursors>=0.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (0.5.2)
# Requirement already satisfied: unidecode>=1.0.0 in c:\python311\lib\site-packages (from python-doctr[torch]) (1.3.6)
# Requirement already satisfied: tqdm>=4.30.0 in c:\python311\lib\site-packages (from python-doctr[torch]) (4.65.0)
# Requirement already satisfied: rapidfuzz>=1.6.0 in c:\python311\lib\site-packages (from python-doctr[torch]) (2.15.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (0.14.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (2.0.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from python-doctr[torch]) (0.15.2)
# Requirement already satisfied: filelock in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (3.12.0)
# Requirement already satisfied: fsspec in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (2023.5.0)
# Requirement already satisfied: requests in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.4.0->python-doctr[torch]) (20.9)
# Requirement already satisfied: six in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from langdetect<2.0.0,>=1.0.9->python-doctr[torch]) (1.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[torch]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[torch]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[torch]) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[torch]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[torch]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from matplotlib>=3.1.0->python-doctr[torch]) (2.8.2)
# Requirement already satisfied: sympy in c:\python311\lib\site-packages (from torch>=1.8.0->python-doctr[torch]) (1.11.1)
# Requirement already satisfied: networkx in c:\python311\lib\site-packages (from torch>=1.8.0->python-doctr[torch]) (3.1)
# Requirement already satisfied: jinja2 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from torch>=1.8.0->python-doctr[torch]) (3.1.2)
# Requirement already satisfied: colorama in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from tqdm>=4.30.0->python-doctr[torch]) (0.4.6)
# Requirement already satisfied: pydyf>=0.6.0 in c:\python311\lib\site-packages (from weasyprint>=55.0->python-doctr[torch]) (0.6.0)
# Requirement already satisfied: cffi>=0.6 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr[torch]) (1.15.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr[torch]) (1.1)
# Requirement already satisfied: tinycss2>=1.0.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr[torch]) (1.2.1)
# Requirement already satisfied: cssselect2>=0.1 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from weasyprint>=55.0->python-doctr[torch]) (0.7.0)
# Requirement already satisfied: Pyphen>=0.9.1 in c:\python311\lib\site-packages (from weasyprint>=55.0->python-doctr[torch]) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\python311\lib\site-packages (from importlib-metadata->python-doctr[torch]) (3.15.0)
# Requirement already satisfied: pycparser in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from cffi>=0.6->weasyprint>=55.0->python-doctr[torch]) (2.21)
# Requirement already satisfied: webencodings in c:\python311\lib\site-packages (from cssselect2>=0.1->weasyprint>=55.0->python-doctr[torch]) (0.5.1)
# Requirement already satisfied: zopfli>=0.1.4 in c:\python311\lib\site-packages (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr[torch]) (0.2.2)
# Requirement already satisfied: brotli>=1.0.1 in c:\python311\lib\site-packages (from fonttools>=4.22.0->matplotlib>=3.1.0->python-doctr[torch]) (1.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from jinja2->torch>=1.8.0->python-doctr[torch]) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr[torch]) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ananda widyatmika\appdata\roaming\python\python311\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr[torch]) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr[torch]) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests->huggingface-hub>=0.4.0->python-doctr[torch]) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in c:\python311\lib\site-packages (from sympy->torch>=1.8.0->python-doctr[torch]) (1.3.0)

# %% [markdown]
# **UserWarning** \
# If warning message pops up, just ignore it.

# %%
import tensorflow as tf
import PyPDF2 as pdf
from doctr.io import DocumentFile
from doctr.models import ocr_predictor
# Out:
# C:\Users\Ananda Widyatmika\AppData\Roaming\Python\Python311\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ## 2. Building Models
# So to make OCR works, we need to combine text detection model and text recognition model as an OCR pipeline to recognize text characters.
#
# ### Text Detection Model
# For the text recognition model, we will use **DB ResNet50**. From the sources that I have read, this model somehow very popular among other document OCR apps for text detection model. It's also recommended by DocTR to use this model instead of the other models. Further research may be needed to understand why this is used.
#
# ### Text Recognition Model
# For the text recognition model, we will use **CRNN VGG-16 Backbone**. Same as ResNet50, this model somehow very popular among other OCR apps for text recognition model. It's also recommended by DocTR to use this model instead of the other models. Further research may needed to understand why this is used.
#
# **Status:** \
# Combining both of these models is somewhat complicated. I have built the models from my local environment, still have no idea how to export it for passing DocTR ocr_predictor arguments. Right now, we will use pretrained model from DocTR itself so it doesn't crash while passing ocr_predictor args. The result from self trained model and pretrained model are nearly the same anyway, so don't worry about it.

# %%
# this block of code will be updated as soon as my self trained models works properly

# %% [markdown]
# ## 3. Extract Text using Trained OCR Models with DocTR
# To extract text with DocTR, we have to use built in ocr_predictor function from DocTR. This function allow us to use self trained or pretrained models for text detection and text recognition. The ocr_predictor returns a document object with a nested structure (with Page, Block, Line, Word, Artefact).

# %%
def extract_with_ocr(file):
    # pretrained model
    model = ocr_predictor(det_arch='db_resnet50', reco_arch='crnn_vgg16_bn', pretrained=True)

    # reading files
    document = DocumentFile.from_pdf(file)

    # analyze
    result = model(document)

    # export to json
    output = result.export()

    # grouping detected words
    separated_words = []
    for page in output["pages"]:
        for block in page["blocks"]:
            for line in block["lines"]:
                for word in line["words"]:
                    separated_words.append(word["value"])
    
    # combining separated words into sentences
    output = " ".join(separated_words)
    
    return output

# %% [markdown]
# The function below is needed to check if the pdf file is a scanned pdf (image based) or digital pdf (text based). If the function didn't detect any characters, it will be considered scanned pdf, so it had to handle extracting text using OCR. If the function detected some characters (100 chars at least) in the pdf file, then it will be considered digital pdf, so it just need to extract text directly from PyPDF2 for better accuracy.
#
# This function return strings of extracted text from the pdf file.

# %%
import re

def text_extractor(file):
    # read file
    reader = pdf.PdfReader(file)
    page = reader.pages[0]
    
    # checks for text
    # if chars detected more than 100 chars, it will be considered scanned pdf
    if len(page.extract_text()) > 100: # tweak this number for character count if you want
        # extract text
        text = page.extract_text()
        
        # clean text
        clean_text = text.lower()

        # remove symbols
        clean_text = re.sub(r'[^\w\ \n]', '', clean_text)
        
        return clean_text
    else:
        return extract_with_ocr(file)

# %% [markdown]
# ## 4. Let's Test It
# This funtion will print out the extracted text from your document. You can play around with any pdf file you want to extract text from. Just change the file_name value to your pdf document path.

# %%
if __name__ == "__main__":
    # test digital pdf
    print("Digital PDF extracted text example:")
    file_name_1 = "example_digital.pdf" # select path to your pdf document in your local environment
    print(text_extractor(file_name_1))
    
    print("="*125)
    
    # test scanned pdf
    print("Scanned PDF extracted text example:")
    file_name_2 = "example_scanned.pdf" # select path to your pdf document in your local environment
    print(text_extractor(file_name_2))
# Out:
# Digital PDF extracted text example:
# janice walton
# janicewaltongmailcom
# 3492618950
#
# objective
# service minded and team focus ed boutique facilitator with 5 years of experience in a luxury retail environment
# eager to support the house of chanel with top class organizational skills and providing the highest standards of
# service in previous roles increased client facing time by over 30 won  facilitator of the year  award
#
# work experience
# boutique facilitator
# balenciaga boutique new york city ny
# 2016 present
#  delivered excellent customer service based on the company values including welcoming and greeting all
# clients analyzing their needs and offering solutions
#  supported the operations division in maintaining stock order and assisting in cycle count activit y
#  opened and closed cash registers and assisted with handling cash and deposits
#  answered phone calls to ensure that all client issues are resolved promptly and professionally
#  maintained the highest professional standards to deliver the ultimate balencia ga experience to the client
# key achievements
#  increased client facing time by 30 thanks to superior communication skills
#  won a prestigious facilitator of the year award presented by the company management to top scorers in
# quarterly customer satisfactio n surveys
#
# alterations specialist
# chloé store new york ny
# 2011 2013
#  oversaw the completion of requested garment alterations within specified deadlines and to the highest
# degree of accuracy possible
#  communicated the alterations room workflow and any ar ising issues to the management team and
# fashion advisors
#  cooperated closely with sales associates to close sales and loyalize customers
#  provide all clients with top class service and professional advice
#  contributed to fostering the company culture of op en communication and cross functional collaboration
# key achievement
#  sewed and altered garments that consistently conformed to the required specifications while meeting 99
# of deadlines
#
# education
# bsc apparel and merchandising
# colorado state univer sity fort collins co
# 2011
#
# key skills
#  luxury fashion merchandising
#  conflict resolution
#  client support
#  communication
#  teamwork
#  organization
#  problem solving
#  analytical skills
#  ms office
#
# languages
#  mandarin communicative
#  french communicative
#
# interests
#  costume design
#  theatre
#
# =============================================================================================================================
# Scanned PDF extracted text example:
# Jane Franklin Douglas-Kelly Professor of English Address University of Pennsylvania Philadelphia, PA 19104, USA Home Address: 713 N 4th St, Philadelphia, PA 19123, USA Phone 267-861-5317 E-mail jane_rankin@gmail.com LinkedIn Inkedin.cominjanefrandlin Twitter twiercom/janemanefmnan Proactive lecturer and researcher with 10+ years of experience teaching courses on undergraduate and postgraduate levels. Supervised 22 BA theses, 9 MA theses, and 2 PhD dissertations. Edited and co-authored 3 monographs on contemporary trends in drama and performative arts. Published over 30 articles in peer-reviewed journals. Education 2000-08 - 2008-05 University of Chicago, Chicago, IL, PhD in Comparative Literature The Department of Modern Laguages Thesis supervisor: Professor George Swan The Department of English Graduated summa cum laude Ideas and Values of the Movement" Thesis supervisor: Professor Anne Plath Academic achievements: Dean's List 2000 Thesis title: "The Lesbianism of Marcel Proust: An Analysis of the Traits of Female Queer Culture in In Search of Lost Time" 1999-08 - 2000-05 City University of New York, New York, NJ, MA in English Thesis title: "Thom Gunn's Peculiar (PosDmodernism: An Analysis of Gunn's Late Works in Comparison to the Awarded "Best Thesis in Modern Languages" 2000 1996-09-1999-07 University of Oxford, Oxford, UK, BA in American Studies Professional Appointments 2014-07 - present Douglas-Kelly Professor of English University of Pennsylvania, Philadelphia, PA the Postgraduate Studies Board from 2014 to 2017. University ofChicago, Chicago, IL courses. Supervised 16 BA theses and 6 MA theses. The Rustle ofLanguage. New York: Hill and Wang Taught a total of 18 undergraduate and 9 postgraduate courses, mainly focused on contemporary conceptual drama and performative arts, as well as experimental poetry and fiction. Supervised 12 MA theses. Member of 2008-08 2013-01 Professor Assistant of English Assisted in developing and executing core curriculum requirements for over 20 under- and postgraduate Books 2017-05 2013-07 2011-01 Sexual Politics in Post-2000 American Drama. Woodstock and New York: The Overlook Press The Man Who Fell. Asleep: Structural Analysis ofNarrative. New York: W. W. Norton & Co.

# %% [markdown]
# ---
# # Summary
# So, this OCR file works just fine. The OCR models predict the words with good accuracy too. But, those models used comes from DocTR pretrained model, so they are already guaranteed that the result of text extraction will be great. Self trained models will be used if they can work properly with DocTR ocr_predictor function args. Some researches may be conducted for reevaluating and remodeling to updgrade and boost accuracy for OCR model.

# %%
# Thanks
